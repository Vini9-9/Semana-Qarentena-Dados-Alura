# %% [markdown]
# # observaçoes iniciais

# %% [markdown]
# * recebi o e-mail as 8:22 da manha horario de cuiaba MT
# * o e-mail fala que trabalharemos na aula com
#     * base de filmes e notas
#     * objetivos
#         * explorar
#         * Questionar
#         * Aprender:
#             * ciencia
#             * Estatistica
#             * Relacionamento de tabelas

# %% [markdown]
# * O e-mail sugere utilizar o colab optei por utilizar o Jupter nootebok e disponibiliza o codigo no github
# * Foi criado um grupo no slack https://datahackers.com.br/slack/?utm_campaign=alura_quarentenadados_-_1_aula&utm_medium=email&utm_source=RD+Station
# * Artigo sobre o colab https://www.alura.com.br/artigos/google-colab-o-que-e-e-como-usar?utm_campaign=alura_quarentenadados_-_1_aula&utm_medium=email&utm_source=RD+Station

# %% [markdown]
# * A aula foi disponibilizada no youtube da alura como não listado
# * https://www.youtube.com/watch?v=TlNQWOUf4Fw&feature=emb_logo
# *

# %% [markdown]
# # Começo da aula

# %% [markdown]
# * o curso é uma parceria entre a Caelun e Alura
# * Data Hacers são apoiadores do curso
# * aula começa depois de 3 minutos

# %%
#Imprimindo nome em tela
print('Leandro Diniz')
# Out:
# Leandro Diniz

# %%
#declarando variavel
nome_do_filme = 'Totoro, O filme'

# %%
#chamando variavel declarada 
print(nome_do_filme)
#ou 
nome_do_filme
# Out:
# Totoro, O filme
# 'Totoro, O filme'

# %% [markdown]
# * Guilherme siveira salvou arquivo dele com nome de QuarentenaDados Filmes

# %%
import pandas as pd

# %%
#pratica adatado por esse analista foi
#1 criei uma pasta src e coloquei os dados lá 
#separarei os dados por aula criando pasta especifica 
filmes = pd.read_csv('src/aula 01/ml-latest-small/movies.csv')

#mostrando os 5 primeiro filmes 
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# * Guilherme siveira orietou a pesquisar sobre a documentação do pandas
# * a participante (não lembro nome) {Thais} informou que pode-se utilizar a interrogação para pequisar de fprma mais generica ex filmes? ou ?filmes.head

# %%
# ?filmes.head

# %%
#pegando arquivo com as notas
notas_dos_filmes = pd.read_csv('src/aula 01/ml-latest-small/ratings.csv')
notas_dos_filmes.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
#Sabendo numero de linhas e colunas
notas_dos_filmes.shape
# Out:
# (100836, 4)

# %%
#sabendo somente numero de linha
print('O numero de linhas da tabela é :')
len(notas_dos_filmes)
# Out:
# O numero de linhas da tabela é :
# 100836

# %% [markdown]
# ##### sabendo o nome das colunas para muda-las para portugues

# %%
# para fazer isso tem pequisar o nome das colunas
notas_dos_filmes.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
#sobrescrevendo o nome das colunas 
notas_dos_filmes.columns = ['usuarioId','filmeId','nota','momento']
notas_dos_filmes.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
#fazendo busca por id especifico dentro da base de csv
#no caso em questão busca-se saber quais as notas do filme com id 1
notas_dos_filmes.query('filmeId==1')
# Out:
#        usuarioId  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 874            7        1   4.5  1106635946
# 1434          15        1   2.5  1510577970
# 1667          17        1   4.5  1305696483
# ...          ...      ...   ...         ...
# 97364        606        1   2.5  1349082950
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [215 rows x 4 columns]

# %% [markdown]
# Qual a nota mazima e minima?

# %%
notas_dos_filmes.describe()
#
# Out:
#            usuarioId        filmeId           nota       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
#Quais valores exatos das notas 
notas_dos_filmes['nota']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %% [markdown]
# ##### Valore medios do filme 1

# %%
notas_dos_filmes.query('filmeId==1').describe()
# Out:
#         usuarioId  filmeId        nota       momento
# count  215.000000    215.0  215.000000  2.150000e+02
# mean   306.530233      1.0    3.920930  1.129835e+09
# std    180.419754      0.0    0.834859  2.393163e+08
# min      1.000000      1.0    0.500000  8.293223e+08
# 25%    155.500000      1.0    3.500000  8.779224e+08
# 50%    290.000000      1.0    4.000000  1.106855e+09
# 75%    468.500000      1.0    4.500000  1.348523e+09
# max    610.000000      1.0    5.000000  1.535710e+09

# %%
#sabendo a media
notas_dos_filmes.query('filmeId==1').mean()
# Out:
# usuarioId    3.065302e+02
# filmeId      1.000000e+00
# nota         3.920930e+00
# momento      1.129835e+09
# dtype: float64

# %%
#sabendo a media só da nota 
notas_dos_filmes.query('filmeId==1')['nota'].mean()
# Out:
# 3.9209302325581397

# %% [markdown]
# ##### Observação
# * a forma adotada não segue conduta de boa praticas
# *  forma correta seira :

# %% [raw]
# notas_filme_1 = notas_dos_filmes['nota']

# %%
#agrupando filmes por id do filme com a media só da coluna nota
notas_dos_filmes.groupby("filmeId")['nota'].mean()
# Out:
# filmeId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: nota, Length: 9724, dtype: float64

# %%
#padronizando e definindo variavel
notas_medias_por_filmes = notas_dos_filmes.groupby("filmeId")['nota'].mean()
notas_medias_por_filmes.head()#esse aqui é uma serie e não um dataframe
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
#Tem que descobrir se todos os dados foram informados

# %%
#vendo quais colunas tem na tabela filmes
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#tem que traduzir o filmes
#tinha coloocado maisculo
filmes.columns = ['filmeId','titulo','genero']
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#fazendo a junção
filmes_com_media = filmes.join(notas_medias_por_filmes, on='filmeId')
filmes_com_media.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genero      nota
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.920930
# 1                   Adventure|Children|Fantasy  3.431818
# 2                               Comedy|Romance  3.259615
# 3                         Comedy|Drama|Romance  2.357143
# 4                                       Comedy  3.071429

# %%
#odenando os dados
#ordenando 1 pelo index ordena de acordo com index
#ordenando 2 pelo values- ordena pelos valores da coluna selecionada
filmes_com_media.sort_values('nota')
# Out:
#       filmeId                              titulo                 genero  nota
# 5554    26696                    Lionheart (1990)                 Action   0.5
# 2689     3604                        Gypsy (1962)                Musical   0.5
# 4881     7312             Follow Me, Boys! (1966)           Comedy|Drama   0.5
# 9117   145724               Idaho Transfer (1973)                 Sci-Fi   0.5
# 7297    76030                      Case 39 (2009)        Horror|Thriller   0.5
# ...       ...                                 ...                    ...   ...
# 5749    30892  In the Realms of the Unreal (2004)  Animation|Documentary   NaN
# 5824    32160            Twentieth Century (1934)                 Comedy   NaN
# 5837    32371           Call Northside 777 (1948)  Crime|Drama|Film-Noir   NaN
# 5957    34482        Browning Version, The (1951)                  Drama   NaN
# 7565    85565                  Chalet Girl (2011)         Comedy|Romance   NaN
#
# [9742 rows x 4 columns]

# %% [markdown]
# ----------------------------
# # Desafios
# ##### Desafio 1
# * 1 descobrir quais os filmes sem notas
# * Fonte: https://pt.stackoverflow.com/questions/309454/contando-valores-nan-e-null-em-um-dataframe-pandas

# %%
filmes_com_media.describe()
# Out:
#              filmeId         nota
# count    9742.000000  9724.000000
# mean    42200.353623     3.262448
# std     52160.494854     0.869874
# min         1.000000     0.500000
# 25%      3248.250000     2.800000
# 50%      7300.000000     3.416667
# 75%     76232.000000     3.911765
# max    193609.000000     5.000000

# %%
#vendo quantos filmes tem 0
filmes_com_media.isnull().sum()
# Out:
# filmeId     0
# titulo      0
# genero      0
# nota       18
# dtype: int64

# %%
consulta = filmes_com_media[filmes_com_media['nota'].isna()]
#verficando se há realmente os 18 dados 
contando_filme_sem_nota = len(filmes_com_media[filmes_com_media['nota'].isna()])

print("A quantidade de filmes que não foram atribuidos notas é de "+str(contando_filme_sem_nota))
print('Os filmes sem notas são esses')
consulta.head(contando_filme_sem_nota)
#contando_filme_sem_nota colocado acima e para fixar o tamanho do header
# Out:
# A quantidade de filmes que não foram atribuidos notas é de 18
# Os filmes sem notas são esses
#       filmeId                                        titulo  \
# 816      1076                         Innocents, The (1961)
# 2211     2939                                Niagara (1953)
# 2499     3338                        For All Mankind (1989)
# 2587     3456  Color of Paradise, The (Rang-e khoda) (1999)
# 3118     4194                I Know Where I'm Going! (1945)
# 4037     5721                            Chosen, The (1981)
# 4506     6668   Road Home, The (Wo de fu qin mu qin) (1999)
# 4598     6849                                Scrooge (1970)
# 4704     7020                                  Proof (1991)
# 5020     7792                     Parallax View, The (1974)
# 5293     8765                      This Gun for Hire (1942)
# 5421    25855                  Roaring Twenties, The (1939)
# 5452    26085                   Mutiny on the Bounty (1962)
# ...

# %% [markdown]
# Solução proposta pela alura

# %% [markdown]
# ##### Desafio 2
# * mudar o nome da colluna nota para mediaNota
# * fonte - https://gist.github.com/leocomelli/2545add34e4fec21ec16

# %%
#modelo - df.rename(columns={'nome': 'nome_completo'})
filmes_com_media.rename(columns = {'nota':'mediaNota'},inplace=True)
filmes_com_media.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genero  mediaNota
# 0  Adventure|Animation|Children|Comedy|Fantasy   3.920930
# 1                   Adventure|Children|Fantasy   3.431818
# 2                               Comedy|Romance   3.259615
# 3                         Comedy|Drama|Romance   2.357143
# 4                                       Comedy   3.071429

# %% [markdown]
# ###### fim do desafio 2
# -----------------------------

# %%
# Ordenando decrescentemente os dados do dataframe
filmes_com_media.sort_values('mediaNota', ascending=False)
# Out:
#       filmeId                                 titulo                 genero  \
# 7656    88448  Paper Birds (Pájaros de papel) (2010)           Comedy|Drama
# 8107   100556             Act of Killing, The (2012)            Documentary
# 9083   143031                        Jump In! (2007)   Comedy|Drama|Romance
# 9094   143511                           Human (2015)            Documentary
# 9096   143559                    L.A. Slasher (2015)   Comedy|Crime|Fantasy
# ...       ...                                    ...                    ...
# 5749    30892     In the Realms of the Unreal (2004)  Animation|Documentary
# 5824    32160               Twentieth Century (1934)                 Comedy
# 5837    32371              Call Northside 777 (1948)  Crime|Drama|Film-Noir
# 5957    34482           Browning Version, The (1951)                  Drama
# 7565    85565                     Chalet Girl (2011)         Comedy|Romance
#
#       mediaNota
# 7656        5.0
# 8107        5.0
# ...

# %% [markdown]
# -------------------
# ##### Desafio 3
# * colocar o número de avaliaçoes por filmes - isto não é a media mas o TOTAL de votos de cada filme

# %%
filmes_com_media
# Out:
#       filmeId                                     titulo  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genero  mediaNota
# 0     Adventure|Animation|Children|Comedy|Fantasy   3.920930
# 1                      Adventure|Children|Fantasy   3.431818
# 2                                  Comedy|Romance   3.259615
# ...

# %%
#recarregando dados para consulta
filmes
# Out:
#       filmeId                                     titulo  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genero
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
#vendo quantos votos o filme obteve
notas_dos_filmes.query('filmeId==1')['filmeId'].count()
# Out:
# 215

# %%
filmes_com_media = filmes.join(notas_medias_por_filmes, on='filmeId')
filmes_com_media.head()
#não consegui
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genero      nota
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.920930
# 1                   Adventure|Children|Fantasy  3.431818
# 2                               Comedy|Romance  3.259615
# 3                         Comedy|Drama|Romance  2.357143
# 4                                       Comedy  3.071429

# %% [markdown]
# metodo da alura

# %%
total_votos_por_filme = notas_dos_filmes.groupby('filmeId')['nota'].count()
total_votos_por_filme.head()
# Out:
# filmeId
# 1    215
# 2    110
# 3     52
# 4      7
# 5     49
# Name: nota, dtype: int64

# %%
filmes_com_media_e_votos = filmes_com_media.join(total_votos_por_filme, on='filmeId', lsuffix='1', rsuffix='2')
filmes_com_media_e_votos = filmes_com_media_e_votos.rename(columns={'nota1': 'Media_de_notas', 'nota2': 'total_votos'})

#classificação do que teve mais votos 
#filtro_decrescente = filmes_com_media_e_votos.sort_values('total_votos', ascending=False)
filmes_com_media_e_votos.head(60)
# Out:
#     filmeId                                             titulo  \
# 0         1                                   Toy Story (1995)
# 1         2                                     Jumanji (1995)
# 2         3                            Grumpier Old Men (1995)
# 3         4                           Waiting to Exhale (1995)
# 4         5                 Father of the Bride Part II (1995)
# 5         6                                        Heat (1995)
# 6         7                                     Sabrina (1995)
# 7         8                                Tom and Huck (1995)
# 8         9                                Sudden Death (1995)
# 9        10                                   GoldenEye (1995)
# 10       11                     American President, The (1995)
# 11       12                 Dracula: Dead and Loving It (1995)
# 12       13                                       Balto (1995)
# 13       14                                       Nixon (1995)
# ...

# %%
filmes_um_voto = filmes_com_media_e_votos.query('total_votos == 1')
filmes_um_voto.head(60)
# Out:
#      filmeId                                             titulo  \
# 45        49                       When Night Is Falling (1995)
# 50        55                                     Georgia (1995)
# 69        77                                   Nico Icon (1995)
# 75        83    Once Upon a Time... When We Were Colored (1995)
# 85        96                      In the Bleak Midwinter (1995)
# 94       106         Nobody Loves Me (Keiner liebt mich) (1994)
# 96       108                                     Catwalk (1996)
# 102      117              Young Poisoner's Handbook, The (1995)
# 110      128                              Jupiter's Wife (1994)
# 111      129                              Pie in the Sky (1996)
# 114      137                             Man of the Year (1995)
# 121      148                   Awfully Big Adventure, An (1995)
# 122      149                                     Amateur (1994)
# 150      178                        Love & Human Remains (1993)
# ...

# %% [markdown]
# Fim do desafio 3
#
# -----------

# %%
notas_medias_por_filmes.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %% [markdown]
# ##### Selecionando dados de filmes desejados
# * 1
# * 2
# * 102084

# %%
filme1 = str(filmes.query('filmeId == 1')['titulo'])
filme2 = str(filmes.query('filmeId == 2')['titulo'])
filme3 = str(filmes.query('filmeId == 102084')['titulo'])
print(filme1,filme2)
# Out:
# 0    Toy Story (1995)
# Name: titulo, dtype: object 1    Jumanji (1995)
# Name: titulo, dtype: object

# %%
#importando matplotlib
import matplotlib.pyplot as plt

#fazendo a quer de avaliação 
notas_dos_filmes.query('filmeId in [1,2,102084]')
# Out:
#        usuarioId  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 560            6        2   4.0   845553522
# 874            7        1   4.5  1106635946
# 1026           8        2   4.0   839463806
# ...          ...      ...   ...         ...
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 98667        608        2   2.0  1117490786
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [326 rows x 4 columns]

# %%
# fazendo filtro somente para o filme 1
notas_dos_filmes.query('filmeId == 1')['nota'].plot(kind='hist',title=filme1)
#plt.title(filme1)
plt.show()#deixando grafico mais bonito

# %%
notas_dos_filmes.query('filmeId == 2')['nota'].plot(kind='hist')
plt.title(filme2)
plt.show()#deixando grafico mais bonito

# %%
notas_dos_filmes.query('filmeId == 102084')['nota'].plot(kind='hist')
plt.title(filme3)
plt.show()#deixando grafico mais bonito

# %% [markdown]
# ---------------------
# ##### desafio 4
# * arredondadar a nota para duas casas decimais
# * fontes:
#     * http://tutoriaiscode.blogspot.com/2017/10/como-converter-int-float-python.html
#     * https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.round.html?highlight=roun#pandas.DataFrame.round

# %%
filmes_com_media['nota'] = round(filmes_com_media['nota'],2)

# %%
filmes_com_media.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genero  nota
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.92
# 1                   Adventure|Children|Fantasy  3.43
# 2                               Comedy|Romance  3.26
# 3                         Comedy|Drama|Romance  2.36
# 4                                       Comedy  3.07

# %%
#classificand

# %% [markdown]
# ###### Resolução alura

# %%
#adaptado
filmes_com_media['nota'] = filmes_com_media['nota'].round(2)
filmes_com_media
# Out:
#       filmeId                                     titulo  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genero  nota
# 0     Adventure|Animation|Children|Comedy|Fantasy  3.92
# 1                      Adventure|Children|Fantasy  3.43
# 2                                  Comedy|Romance  3.26
# ...

# %%
#apliação feita pelo desenvolvedor
#classificação decrescente
filmes_com_media.sort_values('nota', ascending=False)
# Out:
#       filmeId                              titulo  \
# 7080    69860                     Eichmann (2007)
# 9122   145994              Formula of Love (1984)
# 9046   141816                    12 Chairs (1976)
# 5497    26366         Harlan County U.S.A. (1976)
# 7917    95311                       Presto (2008)
# ...       ...                                 ...
# 5749    30892  In the Realms of the Unreal (2004)
# 5824    32160            Twentieth Century (1934)
# 5837    32371           Call Northside 777 (1948)
# 5957    34482        Browning Version, The (1951)
# 7565    85565                  Chalet Girl (2011)
#
#                                  genero  nota
# 7080                          Drama|War   5.0
# 9122                             Comedy   5.0
# 9046                   Adventure|Comedy   5.0
# 5497                        Documentary   5.0
# 7917  Animation|Children|Comedy|Fantasy   5.0
# ...                                 ...   ...
# ...

# %% [markdown]
# Fim desafio 4
#
# ---------------------------------------

# %% [markdown]
# ##### Desafio 5
# * Descobrir os generos do filme(quais são eles,unicos).
# * Quantos generos

# %%
filmes_com_media_e_votos
# Out:
#       filmeId                                     titulo  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genero  Media_de_notas  total_votos
# 0     Adventure|Animation|Children|Comedy|Fantasy        3.920930        215.0
# 1                      Adventure|Children|Fantasy        3.431818        110.0
# ...

# %%
generos_df = filmes_com_media_e_votos.genero.str.get_dummies('|')
generos = generos_df.columns.to_list()
generos
# Out:
# ['(no genres listed)',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Children',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Fantasy',
#  'Film-Noir',
#  'Horror',
#  'IMAX',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Thriller',
#  'War',
#  'Western']

# %%
#traduzir nomes para o portugues
generos_tradução =['Genero não listado','Ação','Aventura','Animação',]
generos
# Out:
# ['(no genres listed)',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Children',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Fantasy',
#  'Film-Noir',
#  'Horror',
#  'IMAX',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Thriller',
#  'War',
#  'Western']

# %% [markdown]
# ##### Desafio 6 contar número de apariçoes de cada genero

# %%
total_filmes_por_genero = filmes_com_media_e_votos.genero.str.get_dummies().sum()
total_filmes_por_genero
# Out:
# (no genres listed)      34
# Action                1828
# Adventure             1263
# Animation              611
# Children               664
# Comedy                3756
# Crime                 1199
# Documentary            440
# Drama                 4361
# Fantasy                779
# Film-Noir               87
# Horror                 978
# IMAX                   158
# Musical                334
# Mystery                573
# Romance               1596
# Sci-Fi                 980
# Thriller              1894
# War                    382
# Western                167
# dtype: int64

# %% [markdown]
# ##### desafio 7 - plotar o grafico de apariçoes de cada genero

# %%
total_filmes_por_genero.sort_values(ascending=False).plot(kind='bar', figsize=(16, 6),title='Grafico da quantidade de genero de Filmes')
plt.show()

# %% [markdown]
# #### Nootebook do desafio
# https://colab.research.google.com/drive/1qTLPYaNm0IJqY5cr6_RwsqCC5SgHznYY

# %% [markdown]
# # aula 2

# %%
filmes['genero'].str.get_dummies().sum()
# Out:
# (no genres listed)      34
# Action                1828
# Adventure             1263
# Animation              611
# Children               664
# Comedy                3756
# Crime                 1199
# Documentary            440
# Drama                 4361
# Fantasy                779
# Film-Noir               87
# Horror                 978
# IMAX                   158
# Musical                334
# Mystery                573
# Romance               1596
# Sci-Fi                 980
# Thriller              1894
# War                    382
# Western                167
# dtype: int64

# %%
filmes['genero'].str.get_dummies().sum().sort_values(ascending=False)
# Out:
# Drama                 4361
# Comedy                3756
# Thriller              1894
# Action                1828
# Romance               1596
# Adventure             1263
# Crime                 1199
# Sci-Fi                 980
# Horror                 978
# Fantasy                779
# Children               664
# Animation              611
# Mystery                573
# Documentary            440
# War                    382
# Musical                334
# Western                167
# IMAX                   158
# Film-Noir               87
# (no genres listed)      34
# dtype: int64

# %%
#Ordenar index
filmes['genero'].str.get_dummies().sum().sort_values(ascending=False).index
# Out:
# Index(['Drama', 'Comedy', 'Thriller', 'Action', 'Romance', 'Adventure',
#        'Crime', 'Sci-Fi', 'Horror', 'Fantasy', 'Children', 'Animation',
#        'Mystery', 'Documentary', 'War', 'Musical', 'Western', 'IMAX',
#        'Film-Noir', '(no genres listed)'],
#       dtype='object')

# %%
#ordenar o valor
filmes['genero'].str.get_dummies().sum().sort_values(ascending=False).values
# Out:
# array([4361, 3756, 1894, 1828, 1596, 1263, 1199,  980,  978,  779,  664,
#         611,  573,  440,  382,  334,  167,  158,   87,   34])

# %%
total_filmes_por_genero.sort_values(ascending=False).plot(
    kind='bar', 
    figsize=(16, 6),
    title='Filmes por categoria')
plt.show()

# %%
import seaborn as sns

# %%
#variavel parachamar a baixo
filmes_por_genero = filmes['genero'].str.get_dummies('|').sum().sort_values(ascending=False)

# %%
sns.set_style('whitegrid')# Adciona o grid ao fundo
plt.figure(figsize=(16, 6))#Coloca o tamanho da figura 
plt.xticks(rotation=45)#rotacionado ticks a 45 grau desafio 01 aula 02

sns.barplot(x=filmes_por_genero.index,
           y=filmes_por_genero.values,
           palette=sns.color_palette('BuGn_r', n_colors=len(filmes_por_genero)+8))#cor da palete

plt.show()

# %% [markdown]
# ##### Desafia 01 dia 02
# # feito acima
#
# * adcionar o numero acima
# * Fonte
#     * https://stackoverflow.com/questions/10998621/rotate-axis-text-in-python-matplotlib

# %%
# fazendo filtro somente para o filme 1
notas_dos_filmes.query('filmeId == 1')['nota'].plot(kind='hist',title=filme1)
#plt.title(filme1)
plt.show()#deixando grafico mais bonito
print('A media do filme é ',notas_dos_filmes.mean()['nota'])
# Out:
# A media do filme é  3.501556983616962

# %%
# fazendo filtro somente para o filme 1
notas_dos_filmes.query('filmeId == 2')['nota'].plot(kind='hist',title=filme1)
#plt.title(filme1)
plt.show()#deixando grafico mais bonito
print('A media do filme é ',notas_dos_filmes.mean()['nota'])
# Out:
# A media do filme é  3.501556983616962

# %% [markdown]
# A media muitas das vezes não retrata a ralidade

# %% [markdown]
# cidade 1

# %%
população = 1000
salario = 11000

media = 1000

# %% [markdown]
# Cidade 2

# %%
população = 1000
salario1 = 1000000#salario de uma pessoa da cidade
salario999 = 100#salario de 999 pessoas da cidade

media = (salario1*1+salario999*999)/população
media
# Out:
# 1099.9

# %% [markdown]
# ### A mediana retrata maias a realidade
# ###### Mediana
#
# A Mediana (Md) é o valor de centro de um conjunto de dados. Para calcular, primeiro devemos ordenar o conjunto de dados.
#
# Para calcular a mediana:
# * Devemos ordenar o conjunto de dados em ordem crescente;
# * Se o número de elementos for par, então a mediana é a média dos dois valores centrais. Soma os dois valores centrais e divide o resultado por 2: (a + b)/2.
# * Se o número de elementos for ímpar, então a mediana é o valor central.

# %%
#criando variavel do filme 2
nota_filme_2 = notas_dos_filmes.query('filmeId == 2')

# %%
#vendo a desrição do filme 2
nota_filme_2.describe()
# Out:
#         usuarioId  filmeId        nota       momento
# count  110.000000    110.0  110.000000  1.100000e+02
# mean   329.554545      2.0    3.431818  1.135805e+09
# std    180.668513      0.0    0.881713  2.362198e+08
# min      6.000000      2.0    0.500000  8.293223e+08
# 25%    171.000000      2.0    3.000000  8.939017e+08
# 50%    322.500000      2.0    3.500000  1.113762e+09
# 75%    481.500000      2.0    4.000000  1.347033e+09
# max    608.000000      2.0    5.000000  1.529902e+09

# %%
nota_filme_1 = notas_dos_filmes.query('filmeId == 1')
nota_filme_1
# Out:
#        usuarioId  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 874            7        1   4.5  1106635946
# 1434          15        1   2.5  1510577970
# 1667          17        1   4.5  1305696483
# ...          ...      ...   ...         ...
# 97364        606        1   2.5  1349082950
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
filmes_com_media.sort_values('nota', ascending=False)[2450:2500]#parte entre cochetes seleciona o intervalo a exibir
# Out:
#       filmeId                                             titulo  \
# 8765   128620                                    Victoria (2015)
# 599       745             Wallace & Gromit: A Close Shave (1995)
# 5480    26258                                    Topo, El (1970)
# 4795     7143                           Last Samurai, The (2003)
# 5451    26084                              Music Man, The (1962)
# 3016     4034                                     Traffic (2000)
# 4100     5876                         Quiet American, The (2002)
# 2894     3871                                       Shane (1953)
# 6580    55247                               Into the Wild (2007)
# 2156     2871                                 Deliverance (1972)
# 7946    95858                               For the Birds (2000)
# 101       116                       Anne Frank Remembered (1995)
# 8533   114935                              Predestination (2014)
# ...

# %%
#definindo função
def plota_filme(n):
    nota = notas_dos_filmes.query(f'filmeId == {n}')['nota']
    nomeFilme = str(filmes.query(f'filmeId == {n}')['titulo'])
    nota.plot(kind='hist',title=nomeFilme)
    return nota.describe()#normamelte função não retorna nada assim e preciso inserir o return

# %%
plota_filme(919)
# Out:
# count    92.000000
# mean      3.880435
# std       1.025418
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# Name: nota, dtype: float64

# %%
plota_filme(46578)
# Out:
# count    77.000000
# mean      3.883117
# std       0.842522
# min       1.000000
# 25%       3.500000
# 50%       4.000000
# 75%       4.500000
# max       5.000000
# Name: nota, dtype: float64

# %% [markdown]
# #### desafio 2
# * compara outros filmes com nota proxima e achar distribuições bem diferentes

# %% [markdown]
# #### Fim desafio 2

# %%
#redefinindo função
def plota_filme_bloxplot(n):
    nota = notas_dos_filmes.query(f'filmeId == {n}')['nota']
    nomeFilme = str(filmes.query(f'filmeId == {n}')['titulo'])
    nota.plot(kind='hist',title=nomeFilme)
    plt.show()#mostra o primeiro grafico
    nota.plot.box(title='mostra onde está grande bloco de notas ou seja 50%')#adciona o boxplot
    plt.show()#mostra o segundo grafico

    return nota.describe()#normamelte função não retorna nada assim e preciso inserir o return

# %%
plota_filme_bloxplot(919)
# Out:
# count    92.000000
# mean      3.880435
# std       1.025418
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# Name: nota, dtype: float64

# %%
plota_filme_bloxplot(46578)
# Out:
# count    77.000000
# mean      3.883117
# std       0.842522
# min       1.000000
# 25%       3.500000
# 50%       4.000000
# 75%       4.500000
# max       5.000000
# Name: nota, dtype: float64

# %% [markdown]
# ----
# #### desafio 3 - Criar o boxplot dos 10 filmes com mais votos(não é com a media e com mais votos)

# %% [markdown]
# #### Fim do desafio 3
# ---

# %%
notas_dos_filmes
# Out:
#         usuarioId  filmeId  nota     momento
# 0               1        1   4.0   964982703
# 1               1        3   4.0   964981247
# 2               1        6   4.0   964982224
# 3               1       47   5.0   964983815
# 4               1       50   5.0   964982931
# ...           ...      ...   ...         ...
# 100831        610   166534   4.0  1493848402
# 100832        610   168248   5.0  1493850091
# 100833        610   168250   5.0  1494273047
# 100834        610   168252   5.0  1493846352
# 100835        610   170875   3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
sns.boxplot(data= notas_dos_filmes.query('filmeId in [1,2,3,919,46578]'),x='filmeId',y='nota')

# %% [markdown]
# ----
# #### desafio 4
# * Criar o boxplot estar em um tamanho adequado
# * legenda nos thicks

# %% [markdown]
# #### Fim desafio 4

# %% [markdown]
# ----
# #### desafio 5
# * calcular
#     * moda
#     * media
#     * mediana
# * Explorar filmes com notas mais proximas 0.5,3,5

# %% [markdown]
# ----
# #### desafio 6
# * plotar o boxplot e o histograma um do lado do outro(no mesmo grafico ou em gráficos distintos)

# %% [markdown]
# ----
# #### desafio 7
# * Gráfico d notas médias por ano

# %% [markdown]
# ----

# %% [markdown]
# ---------
# # Aula 3
#
# Observaçoes - Não tinha realizados os desafios devidos a problemas operacionais mas tentarei realizar sem ver a solução

# %% [markdown]
# ###### Indicaçoes
# * kaggle - repositorio do google com varios nootebooks e base de dados

# %%
# O guilherme da alura pegou os dados do imdb do kaggle jogou os dados no git hub em um gist publico apos
#jogou os dados no pandas como abaixo
imdb = pd.read_csv('https://gist.githubusercontent.com/guilhermesilveira/24e271e68afe8fd257911217b88b2e07/raw/e70287fb1dcaad4215c3f3c9deda644058a616bc/movie_metadata.csv')
imdb.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#sabendo quais os valores unicos no dataframe na serie cor
imdb['color'].unique()
# Out:
# array(['Color', nan, ' Black and White'], dtype=object)

# %%
#contando quantos de cada um 
imdb['color'].value_counts()
# Out:
# Color               4815
#  Black and White     209
# Name: color, dtype: int64

# %%
#vendo a porcentage de cada dado com values counts 
imdb['color'].value_counts(normalize=True)
# Out:
# Color               0.9584
#  Black and White    0.0416
# Name: color, dtype: float64

# %% [markdown]
# #### observação
# * o correto cada uma das series

# %%
#sabendo quantos filmes cada diretor fez
imdb['director_name'].value_counts()
# Out:
# Steven Spielberg     26
# Woody Allen          22
# Clint Eastwood       20
# Martin Scorsese      20
# Ridley Scott         17
#                      ..
# Mars Callahan         1
# Fina Torres           1
# Guillaume Ivernel     1
# Henry King            1
# Joseph Mazzella       1
# Name: director_name, Length: 2398, dtype: int64

# %%
#sabendo quantos filmes cada diretor fez
imdb['director_name'].value_counts().tail(60)#tail define o tamanho de dados que se quer ver
# Out:
# Steven Seagal            1
# Jorge Blanco             1
# Phil Morrison            1
# Garth Jennings           1
# Kevin Jordan             1
# Kaige Chen               1
# Phil Traill              1
# Prachya Pinkaew          1
# Adam Goldberg            1
# Takeshi Kitano           1
# Tim Miller               1
# Bill Duke                1
# Frank LaLoggia           1
# Jack Conway              1
# Peter M. Cohen           1
# Katherine Dieckmann      1
# Stiles White             1
# Anthony Hickox           1
# Natalie Bible'           1
# Jonathan Hensleigh       1
# Mikael Salomon           1
# Gary Chapman             1
# Jackie Earle Haley       1
# Guy Maddin               1
# Matthew O'Callaghan      1
# Paul Hunter              1
# Ash Baron-Cohen          1
# Edward Hall              1
# Keith Gordon             1
# Billy Kent               1
# Joe Chappelle            1
# James Frawley            1
# John Ottman              1
# John McNaughton          1
# ...

# %%
#vendo o numero de votos revistos apos a critica
imdb['num_critic_for_reviews']
# Out:
# 0       723.0
# 1       302.0
# 2       602.0
# 3       813.0
# 4         NaN
#         ...
# 5038      1.0
# 5039     43.0
# 5040     13.0
# 5041     14.0
# 5042     43.0
# Name: num_critic_for_reviews, Length: 5043, dtype: float64

# %%
#saber a nota media por filme 
#primeira solução describe
imdb['num_critic_for_reviews'].describe()
# Out:
# count    4993.000000
# mean      140.194272
# std       121.601675
# min         1.000000
# 25%        50.000000
# 50%       110.000000
# 75%       195.000000
# max       813.000000
# Name: num_critic_for_reviews, dtype: float64

# %%
#para saber se a distribuição está correta plota-se histograma
imdb['num_critic_for_reviews'].plot(kind='hist')

# %%
#sabendo quanto o filme faturou 
imdb['gross'].hist()

# %%
#fazendo mesmo gafico com seaborn
import seaborn as sns
sns.distplot(imdb['gross'])

# %%
#sabendo os fimes que mais faturaram
imdb.sort_values("gross",ascending=False).head()
# Out:
#      color    director_name  num_critic_for_reviews  duration  \
# 0    Color    James Cameron                   723.0     178.0
# 26   Color    James Cameron                   315.0     194.0
# 29   Color  Colin Trevorrow                   644.0     124.0
# 794  Color      Joss Whedon                   703.0     173.0
# 17   Color      Joss Whedon                   703.0     173.0
#
#      director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                        0.0                   855.0   Joel David Moore
# 26                       0.0                   794.0       Kate Winslet
# 29                     365.0                  1000.0         Judy Greer
# 794                      0.0                 19000.0  Robert Downey Jr.
# 17                       0.0                 19000.0  Robert Downey Jr.
#
#      actor_1_facebook_likes        gross                            genres  \
# 0                    1000.0  760505847.0   Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
#sabendo os fimes que mais faturaram
imdb.sort_values("gross",ascending=False).head()['director_name'],['movie_title']
# Out:
# (0        James Cameron
#  26       James Cameron
#  29     Colin Trevorrow
#  794        Joss Whedon
#  17         Joss Whedon
#  Name: director_name, dtype: object,
#  ['movie_title'])

# %%
#pegando 20 filmes aleatorios 
#bom para separa uma parte dos dadoos para analise
imdb.sort_values("gross",ascending=False).sample(20)
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 423              Color        Tarsem Singh                   382.0     106.0
# 825              Color   Anthony Hemingway                   144.0     125.0
# 4686             Color  Christopher Hutson                     8.0      95.0
# 3019             Color        Mary Lambert                    98.0     103.0
# 2817             Color            Bo Zenga                    45.0      90.0
# 3403             Color          Anna Boden                   163.0     101.0
# 1562             Color     Martin Scorsese                   163.0     121.0
# 1885             Color          Ethan Coen                   488.0     122.0
# 3593   Black and White     Stephen Hopkins                    88.0      89.0
# 3749             Color     Christine Jeffs                   195.0      91.0
# 3732             Color        Kasi Lemmons                    31.0     109.0
# ...

# %%
imdb.sort_values("gross",ascending=False)['movie_title']
# Out:
# 0                          Avatar
# 26                        Titanic
# 29                 Jurassic World
# 794                  The Avengers
# 17                   The Avengers
#                    ...
# 5032                         Bang
# 5036              The Mongol King
# 5038      Signed Sealed Delivered
# 5039    The Following
# 5040         A Plague So Pleasant
# Name: movie_title, Length: 5043, dtype: object

# %%
# excluido dados do imdb onde color for igual a NaN
colorido_ou_pretoebranco = imdb.query("color in ['Color', ' Black and White']")
# O comando acima seleciona somente os filmes que tiverem cor ou que forem preto e branco

#vendo a quantidade de filmes que sobraram
len(colorido_ou_pretoebranco)
# Out:
# 5024

# %%
#criando uma coluna 0 ou 1
#ajuda o amigo do telegran
colorido_ou_pretoebranco["color_0_ou_1"] = (colorido_ou_pretoebranco["color"]=="Color")*1 #*1 é uma gambiarra se for verdadeiro
# primeira parte adciona ao data frame uma coluna|serie
# depois do = faz a verificação se na serie color for igual a 'color'(colorido) faz o valor * 1
# o valor se for falso será 0
#lembrando a velha equação matematica
colorido_ou_pretoebranco
# Out:
# /home/leandro/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# ...

# %%
#Mostrando no histograma quais filmes faturam mais preto e branco ou colorido
sns.scatterplot(data=colorido_ou_pretoebranco, x='color_0_ou_1', y='gross')

# %%
#vendo faturamento medio do filme
#agrupa pela cor do filme
#faz a media
#por fim mostra só a media de ganho
consulta_media_colorido_pretoebranco = colorido_ou_pretoebranco.groupby('color').mean()['gross']
consulta_media_colorido_pretoebranco
# Out:
# color
#  Black and White    3.245702e+07
# Color               4.902619e+07
# Name: gross, dtype: float64

# %%
consulta_media_colorido_pretoebranco.plot(kind='bar')

# %%
consulta_media_colorido_pretoebranco_imdb_score = colorido_ou_pretoebranco.groupby('color').mean()['imdb_score']
consulta_media_colorido_pretoebranco_imdb_score
# Out:
# color
#  Black and White    7.227273
# Color               6.409533
# Name: imdb_score, dtype: float64

# %%
plt.xticks(rotation=45)
consulta_media_colorido_pretoebranco_imdb_score.plot(kind='bar')

# %% [markdown]
# -----
# ### desafio 1
# * plotar o boxplot de media do colorido e do preto e branco

# %%
boxsplot = colorido_ou_pretoebranco.groupby('["color"]=="Color"').mean()['gross']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-860b7d75d289> in <module>
# ----> 1 boxsplot = colorido_ou_pretoebranco.groupby('["color"]=="Color"').mean()['gross']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# ...

# %%
boxsplot.plot.box(title='mostra onde está grande bloco de notas ou seja 50%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-6a5f6cf10f6f> in <module>
# ----> 1 boxsplot.plot.box(title='mostra onde está grande bloco de notas ou seja 50%')
#
# NameError: name 'boxsplot' is not defined

# %% [markdown]
# ###### fim desafio
# ___

# %%
#Vendo a influencia do invetimento sobre o faturamento
#imdb[["budget","gross"]] - Seleciona somente as colunas 
#.dropna() - exclui os dados com NaN
#query consulta especifica
#| pipe - equivale a or
Investimento_faturamento = imdb[["budget","gross"]].dropna().query("budget > 0 | gross < 0")

#plota o grafico
#sns - biblioteca 
#scatterplot - grafico que se quer plotar 
# x y - serie que se quer plotar 
#data -dados que se quer plotar - chamei a variavel que coloquei acima
sns.scatterplot(x = "budget", y = "gross",data = Investimento_faturamento )

# %%
imdb.sort_values('budget',ascending=False).head()
# Out:
#       color    director_name  num_critic_for_reviews  duration  \
# 2988  Color     Joon-ho Bong                   363.0     110.0
# 3859  Color   Chan-wook Park                   202.0     112.0
# 3005  Color     Lajos Koltai                    73.0     134.0
# 2323  Color   Hayao Miyazaki                   174.0     134.0
# 2334  Color  Katsuhiro Ôtomo                   105.0     103.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 2988                    584.0                    74.0        Kang-ho Song
# 3859                      0.0                    38.0        Yeong-ae Lee
# 3005                     45.0                     0.0     Péter Fancsikai
# 2323                   6000.0                   745.0  Jada Pinkett Smith
# 2334                     78.0                   101.0  Robin Atkin Downes
#
#       actor_1_facebook_likes      gross  \
# 2988                   629.0  2201412.0
# 3859                   717.0   211667.0
# ...

# %%
#vendo paises
imdb['country'].unique()
# Out:
# array(['USA', 'UK', nan, 'New Zealand', 'Canada', 'Australia', 'Belgium',
#        'Japan', 'Germany', 'China', 'France', 'New Line', 'Mexico',
#        'Spain', 'Hong Kong', 'Czech Republic', 'India', 'Soviet Union',
#        'South Korea', 'Peru', 'Italy', 'Russia', 'Aruba', 'Denmark',
#        'Libya', 'Ireland', 'South Africa', 'Iceland', 'Switzerland',
#        'Romania', 'West Germany', 'Chile', 'Netherlands', 'Hungary',
#        'Panama', 'Greece', 'Sweden', 'Norway', 'Taiwan', 'Official site',
#        'Cambodia', 'Thailand', 'Slovakia', 'Bulgaria', 'Iran', 'Poland',
#        'Georgia', 'Turkey', 'Nigeria', 'Brazil', 'Finland', 'Bahamas',
#        'Argentina', 'Colombia', 'Israel', 'Egypt', 'Kyrgyzstan',
#        'Indonesia', 'Pakistan', 'Slovenia', 'Afghanistan',
#        'Dominican Republic', 'Cameroon', 'United Arab Emirates', 'Kenya',
#        'Philippines'], dtype=object)

# %%
len(imdb)
# Out:
# 5043

# %%
#removendo dados duplicados
imdb_sem_duplicados = imdb.drop_duplicates()

# %%
len(imdb_sem_duplicados)
# Out:
# 4998

# %%
#selecionando somente filmes dos estados Unidos 
imdb_usa = imdb_sem_duplicados.query("country == 'USA'")
imdb_usa.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
# 6                      0.0                  4000.0      James Franco
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
imdb_usa.sort_values('budget',ascending=False).head()
# Out:
#       color   director_name  num_critic_for_reviews  duration  \
# 1     Color  Gore Verbinski                   302.0     169.0
# 5     Color  Andrew Stanton                   462.0     132.0
# 7     Color    Nathan Greno                   324.0     100.0
# 6     Color       Sam Raimi                   392.0     156.0
# 3461  Color       Sam Raimi                   392.0     156.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 1                       563.0                  1000.0    Orlando Bloom
# 5                       475.0                   530.0  Samantha Morton
# 7                        15.0                   284.0     Donna Murphy
# 6                         0.0                  4000.0     James Franco
# 3461                      0.0                  4000.0     James Franco
#
#       actor_1_facebook_likes        gross  \
# 1                    40000.0  309404152.0
# 5                      640.0   73058679.0
# ...

# %%
#Vendo a influencia do invetimento sobre o faturamento
#imdb[["budget","gross"]] - Seleciona somente as colunas 
#.dropna() - exclui os dados com NaN
#query consulta especifica
#| pipe - equivale a or
Investimento_faturamento = imdb_usa[["budget","gross"]].dropna().query("budget > 0 | gross < 0")

#plota o grafico
#sns - biblioteca 
#scatterplot - grafico que se quer plotar 
# x y - serie que se quer plotar 
#data -dados que se quer plotar - chamei a variavel que coloquei acima
sns.scatterplot(x = "budget", y = "gross",data = Investimento_faturamento )

# %%
#lucro X Prejuizo
imdb_usa['lucro'] = imdb_usa["gross"] - imdb_usa["budget"]
#siplismente lucro menos investimento



#Vendo a influencia do invetimento sobre o faturamento
#imdb[["budget","gross"]] - Seleciona somente as colunas 
#.dropna() - exclui os dados com NaN
#query consulta especifica
#| pipe - equivale a or
Investimento_faturamento = imdb_usa.query("budget > 0 | gross > 0")[["budget","lucro"]].dropna()

#plota o grafico
#sns - biblioteca 
#scatterplot - grafico que se quer plotar 
# x y - serie que se quer plotar 
#data -dados que se quer plotar - chamei a variavel que coloquei acima
sns.scatterplot(x = "budget", y = "lucro",data = Investimento_faturamento )
# Out:
# /home/leandro/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# -----
# # aula 3
# ##### desafio 2
# * quem gastou mais e de o prejuizo proximo do 2.5?

# %% [markdown]
# ##### fim do desafio
# -----

# %% [markdown]
# -----
# # aula 3
# ##### desafio 3
# * Filmes mais recentes tiveram mais prejuizo?

# %% [markdown]
# ##### fim do desafio
# -----

# %%
#parei em 45 minutos
