# %% [markdown]
# # Aula04
# * o guilherme silveira baixou os dados direto inep com base nos dados de 2018.
# * codigo de boa praticas diz que para teste e bo usar um sample
# * o Guilherme apresentou em seu github https://github.com/guilhermesilveira/enem-2018

# %%
uri = 'https://raw.githubusercontent.com/guilhermesilveira/enem-2018/master/MICRODADOS_ENEM_2018_SAMPLE_43278.csv'

# %%
import pandas as pd

dados = pd.read_csv(uri)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0  180009327796    2018                  2112209                   Timon
# 1  180012890374    2018                  3557105             Votuporanga
# 2  180008223824    2018                  2506301               Guarabira
# 3  180007859645    2018                  3534807              Ouro Verde
# 4  180013499517    2018                  3523107         Itaquaquecetuba
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                21               MA      34.0       M              1.0
# 1                35               SP      14.0       M              0.0
# 2                25               PB      20.0       F              0.0
# 3                35               SP      17.0       F              0.0
# 4                35               SP      19.0       M              0.0
#
#    TP_COR_RACA  ...  Q018  Q019 Q020  Q021 Q022  Q023  Q024  Q025  Q026  Q027
# ...

# %%
dados.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        ...
#        'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025', 'Q026',
#        'Q027'],
#       dtype='object', length=137)

# %%
#describe só descreve dados de colunas numericas

dados.describe()
# Out:
#        NU_INSCRICAO    NU_ANO  CO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# count  1.378440e+05  137844.0             1.378440e+05     137844.000000
# mean   1.800104e+11    2018.0             3.118377e+06         31.030701
# std    1.918950e+06       0.0             9.944830e+05          9.916221
# min    1.800072e+11    2018.0             1.100015e+06         11.000000
# 25%    1.800088e+11    2018.0             2.409100e+06         24.000000
# 50%    1.800104e+11    2018.0             3.137700e+06         31.000000
# 75%    1.800120e+11    2018.0             3.550308e+06         35.000000
# max    1.800140e+11    2018.0             5.300108e+06         53.000000
#
#             NU_IDADE  TP_ESTADO_CIVIL    TP_COR_RACA  TP_NACIONALIDADE  \
# count  137843.000000    132485.000000  137844.000000     137844.000000
# mean       22.378967         0.120655       2.123204          1.039001
# std         7.610313         0.376805       1.017945          0.231610
# ...

# %%
colunas_de_notas = ['NU_NOTA_CN', 'NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO']
dados_nota = dados[colunas_de_notas]

# %%
quantidade = len(dados_nota)
dados_nota.head()
# Out:
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0         NaN         NaN         NaN         NaN              NaN
# 1       523.1       671.3       661.6       738.0            680.0
# 2       409.2       531.7       389.0       438.1            600.0
# 3       452.3       505.5       448.5       544.9            400.0
# 4         NaN         NaN         NaN         NaN              NaN

# %%
print(quantidade)
# Out:
# 137844

# %%
#jogando valores NaN fora da base de dados
dados_nota = dados[colunas_de_notas].dropna()
dados_nota.head()
# Out:
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 1       523.1       671.3       661.6       738.0            680.0
# 2       409.2       531.7       389.0       438.1            600.0
# 3       452.3       505.5       448.5       544.9            400.0
# 6       428.5       505.2       521.0       436.8            560.0
# 8       491.8       575.7       524.4       487.6            660.0

# %%
len(dados_nota)
# Out:
# 97270

# %% [markdown]
# #### desafio1
# * se não tiver presente substituir a nota 0? a nota media? a mediana?

# %%
dados_nota.columns = ['Ciencias_Natuarais', 'Ciencias_Humanas','Linguagem_Codigo','Matematica','redacao']
dados_nota.head()
# Out:
#    Ciencias_Natuarais  Ciencias_Humanas  Linguagem_Codigo  Matematica  redacao
# 1               523.1             671.3             661.6       738.0    680.0
# 2               409.2             531.7             389.0       438.1    600.0
# 3               452.3             505.5             448.5       544.9    400.0
# 6               428.5             505.2             521.0       436.8    560.0
# 8               491.8             575.7             524.4       487.6    660.0

# %%
corr = dados_nota.corr()
corr.head()
# Out:
#                     Ciencias_Natuarais  Ciencias_Humanas  Linguagem_Codigo  \
# Ciencias_Natuarais            1.000000          0.571979          0.600252
# Ciencias_Humanas              0.571979          1.000000          0.698270
# Linguagem_Codigo              0.600252          0.698270          1.000000
# Matematica                    0.579052          0.529275          0.565544
# redacao                       0.513206          0.502914          0.562957
#
#                     Matematica   redacao
# Ciencias_Natuarais    0.579052  0.513206
# Ciencias_Humanas      0.529275  0.502914
# Linguagem_Codigo      0.565544  0.562957
# Matematica            1.000000  0.483313
# redacao               0.483313  1.000000

# %%
#imprimindo correlação com seaborn 

from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.003, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot = True)

# %%
sns.heatmap(corr, mask=mask,  annot = True, )

# %%
sns.pairplot(dados_nota)

# %%
sns.pairplot(dados_nota, kind='reg')

# %% [markdown]
# # Desafio
# * Resolver o problema da matriz de correlação

# %% [markdown]
# ###### Resolução Leandro

# %%
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap= 'coolwarm', center=0
            , cbar_kws={"shrink": .5}, annot = True)


plt.show()

# Reseta as configurações para o padrão
sns.set()

# %% [markdown]
# **proposta de resolução alura**

# %%
sns.set(font_scale=1.2)

labels = ['Ciências da Natureza', 'Ciências Humanas', 'Linguagens e Códigos', 'Matemática', 'Redação']
#determina nome das labels

plt.figure(figsize=(6, 6))#fixa tamnho da figura 
ax = sns.heatmap(
    corr,#dados do corr
    annot=True,
    cmap="YlGnBu",
    cbar=False,
    xticklabels=labels,
    yticklabels=labels,
    # mask=np.triu(np.ones_like(corr, dtype=np.bool))
)

plt.show()

# Reseta as configurações para o padrão
sns.set()

# %% [markdown]
# ### Desafio
# * pairplot dos acertos de cada categoria(CN,CH,MT,LC, nota pura da redação) usar o gabarito e as respostas

# %% [markdown]
# ### Desafio
# * verificar se é faltante
# * Remover todos os zeros

# %% [markdown]
# ### Desafio
# * Remover todos os zeros

# %% [markdown]
# ### Desafio
# * Estudar o que as pessoas que estudam o assunto estão discutindo e conclusoes que já chegaram sobre a utilização de informações sensiveis para machine learning e data science.
#     * podcast
#         * Datahackers
#         * hipsters

# %% [markdown]
# # Aula 05

# %% [markdown]
# ### advinha a nota da redação com base nos outros ?\

# %%
sns.pairplot(dados_nota)

# %% [raw]
# treino 11 = 2
# treino 22 = 4
# treino 34 = 7
# treino 21 = 3
#
# teste 54 = 9

# %%
tenho = dados_nota[['Ciencias_Natuarais', 'Ciencias_Humanas','Matematica','redacao']]
tenho.head()
# Out:
#    Ciencias_Natuarais  Ciencias_Humanas  Matematica  redacao
# 1               523.1             671.3       738.0    680.0
# 2               409.2             531.7       438.1    600.0
# 3               452.3             505.5       544.9    400.0
# 6               428.5             505.2       436.8    560.0
# 8               491.8             575.7       487.6    660.0

# %%
advinhar = dados_nota['Linguagem_Codigo']
advinhar
# Out:
# 1         661.6
# 2         389.0
# 3         448.5
# 6         521.0
# 8         524.4
#           ...
# 137835    504.8
# 137836    528.5
# 137838    538.3
# 137840    468.1
# 137842    527.7
# Name: Linguagem_Codigo, Length: 97270, dtype: float64

# %% [raw]
# O que quero é uma funçao que fara a seguinte equação
# f(x)===y
# x = tenho
# y = advinhar
# mudando o codigo

# %%
x = tenho
y = advinhar

# %%
x.head()
# Out:
#    Ciencias_Natuarais  Ciencias_Humanas  Matematica  redacao
# 1               523.1             671.3       738.0    680.0
# 2               409.2             531.7       438.1    600.0
# 3               452.3             505.5       544.9    400.0
# 6               428.5             505.2       436.8    560.0
# 8               491.8             575.7       487.6    660.0

# %%
y
# Out:
# 1         661.6
# 2         389.0
# 3         448.5
# 6         521.0
# 8         524.4
#           ...
# 137835    504.8
# 137836    528.5
# 137838    538.3
# 137840    468.1
# 137842    527.7
# Name: Linguagem_Codigo, Length: 97270, dtype: float64

# %% [markdown]
# **chamando o skelarn**

# %%
from sklearn.model_selection import train_test_split

#Separando entre treino e terte
train_test_split(x,y)
# Out:
# [        Ciencias_Natuarais  Ciencias_Humanas  Matematica  redacao
#  39119                512.0             626.3       525.4    600.0
#  129200               481.4             413.5       499.7    480.0
#  51549                645.0             651.7       752.3    740.0
#  76086                500.7             564.8       466.9    400.0
#  38271                479.4             421.2       498.9    360.0
#  ...                    ...               ...         ...      ...
#  126491               457.1             612.5       440.8    820.0
#  48122                381.4             414.7       489.8    400.0
#  311                  464.2             596.8       483.2    740.0
#  61855                433.5             465.8       425.4    540.0
#  103706               426.2             492.7       383.6    280.0
#
#  [72952 rows x 4 columns],
#          Ciencias_Natuarais  Ciencias_Humanas  Matematica  redacao
#  132406               406.1             424.8       395.0    460.0
# ...

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y)

# %% [markdown]
# **Vendo a porcentagem de treino e teste**

# %%
print(x_treino.shape)
print(x_teste.shape)
print(y_treino.shape)
print(y_teste.shape)
# Out:
# (72952, 4)
# (24318, 4)
# (72952,)
# (24318,)

# %% [markdown]
# ### **Definindo SEED de definição de modo a não ser um sistema randomico**
# * IMPORTAR O NUMPY DE NUMERO RANDOMICOS

# %%
import numpy as np

#setando seed do numpy
np.random.seed(43267)

x_treino, x_teste, y_treino, y_teste = train_test_split(x,y,random_state = 326784)

print(x_treino.shape)
print(x_teste.shape)
print(y_treino.shape)
print(y_teste.shape)
# Out:
# (72952, 4)
# (24318, 4)
# (72952,)
# (24318,)

# %% [markdown]
# **Estudar a geração de numeros pseudo aleatorios**

# %%
x_treino.head()
# Out:
#        Ciencias_Natuarais  Ciencias_Humanas  Matematica  redacao
# 25012               610.2             651.9       741.4    660.0
# 52044               571.7             639.6       639.1    680.0
# 86543               385.9             569.1       502.0    360.0
# 36362               424.7             446.2       589.8    420.0
# 96734               831.4             850.4       943.2    940.0

# %% [markdown]
# ### treinando usando algoritimo
# * a varios algoritimos

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR()
# por padrão o linea vem sem nenhuma informação 

#comando abaixo inseri as informaçoes de treino
modelo.fit(x_treino, y_treino)
# Out:
# /home/leandro/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#           intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#           random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ______
# ##### Desafio 01
# * brique com os parametro C e max_iter. não há garantias qu o resultado será melhor

# %% [markdown]
# Fazendo o modelo previsto apresentar os dados

# %%
predicoes_notas_linguagem = modelo.predict(x_teste)

#devolve array numpy
predicoes_notas_linguagem[:5]
# Out:
# array([591.30581763, 606.46025242, 639.89298788, 555.97651583,
#        472.52000416])

# %%
y_teste.head()
# Out:
# 67300     577.2
# 113766    624.4
# 48328     703.0
# 9454      598.6
# 9515      458.6
# Name: Linguagem_Codigo, dtype: float64

# %% [markdown]
# **vendo dados plotados em um grafico**

# %%
import matplotlib.pyplot as plt

#deixando o grafico quadrado
plt.figure(figsize=(10,10))


#trasformando  os dois dados em array 

sns.scatterplot(x=y_teste.values,y = predicoes_notas_linguagem)

# %% [markdown]
# Vendo o quanto o modelo matematico errou

# %%
import matplotlib.pyplot as plt

#deixando o grafico quadrado
plt.figure(figsize=(10,10))


#trasformando  os dois dados em array 

sns.scatterplot(x=y_teste.values, y = y_teste.values - predicoes_notas_linguagem)

# %%
#vendo a diferença 
y_teste - x_teste.mean(axis=1)
# Out:
# 67300     -29.900
# 113766     -6.225
# 48328      47.075
# 9454       53.150
# 9515      -32.900
#            ...
# 32842      30.625
# 42388     -55.850
# 55278      -9.775
# 41511     113.375
# 62897      27.625
# Length: 24318, dtype: float64

# %% [markdown]
# **predição TOSCA guilherme**

# %%
#plotando os dados acimas em grafico para ver a diferença de forma visual
import matplotlib.pyplot as plt

#deixando o grafico quadrado
plt.figure(figsize=(10,10))


#trasformando  os dois dados em array 

sns.scatterplot(x=y_teste.values, y = y_teste - x_teste.mean(axis=1))

# %% [markdown]
# **predição TOSCA Paulo Silveira**

# %%
#plotando os dados acimas em grafico para ver a diferença de forma visual
import matplotlib.pyplot as plt

#deixando o grafico quadrado
plt.figure(figsize=(10,10))


#trasformando  os dois dados em array 

sns.scatterplot(x=y_teste.values, y = y_teste - y_teste.mean())
plt.show()

# %%
from sklearn.svm import SVR

modelo = SVR()
# por padrão o linea vem sem nenhuma informação 

#comando abaixo inseri as informaçoes de treino
modelo.fit(x_treino, y_treino)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
predicoes_notas_linguagem = modelo.predict(x_teste)

#devolve array numpy
predicoes_notas_linguagem[:5]
# Out:
# array([598.06286738, 603.4699406 , 633.46945752, 553.14805238,
#        482.72696471])

# %%
y_teste.head()
# Out:
# 67300     577.2
# 113766    624.4
# 48328     703.0
# 9454      598.6
# 9515      458.6
# Name: Linguagem_Codigo, dtype: float64

# %%
import matplotlib.pyplot as plt

#deixando o grafico quadrado
plt.figure(figsize=(10,10))


#trasformando  os dois dados em array 

sns.scatterplot(x=y_teste.values,y = predicoes_notas_linguagem)

# %%
import matplotlib.pyplot as plt

#deixando o grafico quadrado
plt.figure(figsize=(10,10))


#trasformando  os dois dados em array 

sns.scatterplot(x=y_teste.values, y = y_teste.values - predicoes_notas_linguagem)

# %%
from sklearn.tree import DecisionTreeRegressor

modelo = DecisionTreeRegressor()
# por padrão o linea vem sem nenhuma informação 

#comando abaixo inseri as informaçoes de treino
modelo.fit(x_treino, y_treino)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
import matplotlib.pyplot as plt

#deixando o grafico quadrado
plt.figure(figsize=(10,10))


#trasformando  os dois dados em array 

sns.scatterplot(x=y_teste.values,y = predicoes_notas_linguagem)

# %%
import matplotlib.pyplot as plt

#deixando o grafico quadrado
plt.figure(figsize=(10,10))


#trasformando  os dois dados em array 

sns.scatterplot(x=y_teste.values, y = predicoes_notas_linguagem)

# %%
#deixando o grafico quadrado
plt.figure(figsize=(10,10))

sns.scatterplot(x = x_teste['Matematica'].values, y = predicoes_notas_linguagem)
sns.scatterplot(x = x_teste['Matematica'].values, y = y_teste.values)

# %% [markdown]
# ### Desafio
# * plotar no eixo X a média das 4 notas ao inves de uma só

# %% [markdown]
# #### vendo a diferença do erro

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_teste, predicoes_notas_linguagem)
# Out:
# 2050.1939603631563

# %%
from sklearn.dummy import DummyRegressor
# por padrão o algoritimo usa a media

modelo_dummy = DummyRegressor()
modelo_dummy.fit(x_treino,y_treino)
dummy_predicoes = modelo_dummy.predict(x_teste)

mean_squared_error(y_teste, dummy_predicoes)
# Out:
# 5137.479089212121

# %%
#mundando para a mediana como dummy
modelo_dummy = DummyRegressor('median')
modelo_dummy.fit(x_treino,y_treino)
dummy_predicoes = modelo_dummy.predict(x_teste)

mean_squared_error(y_teste, dummy_predicoes)
# Out:
# 5160.291908051649

# %% [markdown]
# #### Desafio
# * Interpetre o que você fez e a sua conclusão.

# %% [markdown]
# #### Desafio
# * Calcule as metricas de erro que utilizamos (mean square root error)
# * Também no conjunto de treino
# * veja o que acontece comparando o conjunto de teste
